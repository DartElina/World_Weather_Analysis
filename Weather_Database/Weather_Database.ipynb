# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import time

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
vacation_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        vacation_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | taguatinga
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | kovernino
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | namie
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | takoradi
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | warrington
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ahipara
# Processing Record 20 of Set 1 | nantucket
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 1 | suhbaatar
# Processing Record 28 of Set 1 | nampula
# Processing Record 29 of Set 1 | homer
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 1 | utica
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | lashma
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | williston
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | asau
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | skjervoy
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | kamenka
# Processing Record 4 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | araouane
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | denpasar
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | margate
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | taoudenni
# Processing Record 13 of Set 2 | north platte
# Processing Record 14 of Set 2 | veraval
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | samagaltay
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | vardo
# Processing Record 25 of Set 2 | viransehir
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | dungarvan
# Processing Record 29 of Set 2 | alyangula
# Processing Record 30 of Set 2 | jimma
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | atyashevo
# Processing Record 34 of Set 2 | banda aceh
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | namibe
# Processing Record 37 of Set 2 | micheweni
# Processing Record 38 of Set 2 | trincomalee
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | khash
# Processing Record 41 of Set 2 | cururupu
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | santa clarita
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | jalu
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | sakakah
# Processing Record 48 of Set 2 | rognan
# Processing Record 49 of Set 2 | altay
# Processing Record 50 of Set 2 | taltal
# Processing Record 1 of Set 3 | bonavista
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | pine bluff
# Processing Record 4 of Set 3 | necochea
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | caraz
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | nanortalik
# Processing Record 10 of Set 3 | menongue
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | bereda
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | grays
# Processing Record 16 of Set 3 | callaguip
# Processing Record 17 of Set 3 | ryotsu
# Processing Record 18 of Set 3 | hofn
# Processing Record 19 of Set 3 | baykit
# Processing Record 20 of Set 3 | khatra
# Processing Record 21 of Set 3 | miri
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | tual
# Processing Record 25 of Set 3 | izhmorskiy
# Processing Record 26 of Set 3 | fredericton
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | beyneu
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | xiongshi
# City not found. Skipping...
# Processing Record 31 of Set 3 | krasnovka
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | springfield
# Processing Record 35 of Set 3 | garowe
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | misratah
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | yuci
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | pacific grove
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | killybegs
# Processing Record 45 of Set 3 | farafangana
# Processing Record 46 of Set 3 | zolnoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | mirante do paranapanema
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | neuquen
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | portland
# Processing Record 4 of Set 4 | potosi
# Processing Record 5 of Set 4 | vuktyl
# Processing Record 6 of Set 4 | liverpool
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | shelburne
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | manicore
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | villa carlos paz
# Processing Record 14 of Set 4 | empalme
# Processing Record 15 of Set 4 | moultrie
# Processing Record 16 of Set 4 | magdagachi
# Processing Record 17 of Set 4 | grindavik
# Processing Record 18 of Set 4 | nangomba
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | roald
# Processing Record 21 of Set 4 | iskateley
# Processing Record 22 of Set 4 | karratha
# Processing Record 23 of Set 4 | new norfolk
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | laguna
# Processing Record 29 of Set 4 | sterling
# Processing Record 30 of Set 4 | hovd
# Processing Record 31 of Set 4 | katobu
# Processing Record 32 of Set 4 | barahona
# Processing Record 33 of Set 4 | sydney
# Processing Record 34 of Set 4 | port hedland
# Processing Record 35 of Set 4 | molteno
# Processing Record 36 of Set 4 | nivala
# Processing Record 37 of Set 4 | rabak
# Processing Record 38 of Set 4 | pearl river
# Processing Record 39 of Set 4 | urumqi
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | klaksvik
# Processing Record 44 of Set 4 | labuhan
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | half moon bay
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | tongren
# Processing Record 49 of Set 4 | broken hill
# Processing Record 50 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | asosa
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | mersing
# Processing Record 6 of Set 5 | atar
# Processing Record 7 of Set 5 | raudeberg
# Processing Record 8 of Set 5 | chhindwara
# Processing Record 9 of Set 5 | madera
# Processing Record 10 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | jatiroto
# Processing Record 12 of Set 5 | elizabeth city
# Processing Record 13 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 5 | campo grande
# Processing Record 15 of Set 5 | toora-khem
# Processing Record 16 of Set 5 | haimen
# Processing Record 17 of Set 5 | voznesenskaya
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | samarai
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | pedernales
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | male
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | huixtla
# Processing Record 26 of Set 5 | sinnamary
# Processing Record 27 of Set 5 | pangnirtung
# Processing Record 28 of Set 5 | riviere-au-renard
# Processing Record 29 of Set 5 | berlevag
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | nador
# Processing Record 32 of Set 5 | berea
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | maldonado
# Processing Record 35 of Set 5 | maniitsoq
# Processing Record 36 of Set 5 | cruz alta
# Processing Record 37 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 38 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 5 | vila velha
# Processing Record 40 of Set 5 | tasiilaq
# Processing Record 41 of Set 5 | trat
# Processing Record 42 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 5 | te anau
# Processing Record 44 of Set 5 | novoagansk
# Processing Record 45 of Set 5 | batemans bay
# Processing Record 46 of Set 5 | aksha
# Processing Record 47 of Set 5 | orbe
# Processing Record 48 of Set 5 | bedele
# Processing Record 49 of Set 5 | yakeshi
# Processing Record 50 of Set 5 | dunedin
# Processing Record 1 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 6 | nizhniy odes
# Processing Record 3 of Set 6 | robertson
# Processing Record 4 of Set 6 | guanica
# Processing Record 5 of Set 6 | dingtao
# Processing Record 6 of Set 6 | marawi
# Processing Record 7 of Set 6 | kutum
# Processing Record 8 of Set 6 | hilton head island
# Processing Record 9 of Set 6 | robertsport
# Processing Record 10 of Set 6 | antissa
# City not found. Skipping...
# Processing Record 11 of Set 6 | komsomolskiy
# Processing Record 12 of Set 6 | nouadhibou
# Processing Record 13 of Set 6 | skibbereen
# Processing Record 14 of Set 6 | tahoua
# Processing Record 15 of Set 6 | krasnogvardeyets
# Processing Record 16 of Set 6 | zhongshu
# Processing Record 17 of Set 6 | santa barbara
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | madimba
# Processing Record 22 of Set 6 | juneau
# Processing Record 23 of Set 6 | eldorado
# Processing Record 24 of Set 6 | tezu
# Processing Record 25 of Set 6 | jiaozuo
# Processing Record 26 of Set 6 | udachnyy
# Processing Record 27 of Set 6 | mashhad
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | tessalit
# Processing Record 30 of Set 6 | tautira
# Processing Record 31 of Set 6 | ayotzintepec
# Processing Record 32 of Set 6 | lerwick
# Processing Record 33 of Set 6 | batagay
# Processing Record 34 of Set 6 | mentakab
# Processing Record 35 of Set 6 | gushikawa
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | verkhnyaya inta
# Processing Record 38 of Set 6 | faya
# Processing Record 39 of Set 6 | qui nhon
# Processing Record 40 of Set 6 | wangdiphodrang
# City not found. Skipping...
# Processing Record 41 of Set 6 | matagami
# Processing Record 42 of Set 6 | horadiz
# Processing Record 43 of Set 6 | inver grove heights
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | nago
# Processing Record 46 of Set 6 | kalmunai
# Processing Record 47 of Set 6 | ishigaki
# Processing Record 48 of Set 6 | inhambane
# Processing Record 49 of Set 6 | lubango
# Processing Record 50 of Set 6 | ulaangom
# Processing Record 1 of Set 7 | sambava
# Processing Record 2 of Set 7 | chuy
# Processing Record 3 of Set 7 | norden
# Processing Record 4 of Set 7 | tocopilla
# Processing Record 5 of Set 7 | kilifi
# Processing Record 6 of Set 7 | bosobolo
# Processing Record 7 of Set 7 | coahuayana
# Processing Record 8 of Set 7 | pisco
# Processing Record 9 of Set 7 | minchinabad
# Processing Record 10 of Set 7 | yaan
# Processing Record 11 of Set 7 | hunchun
# Processing Record 12 of Set 7 | shieli
# Processing Record 13 of Set 7 | manuk mangkaw
# Processing Record 14 of Set 7 | xingyi
# Processing Record 15 of Set 7 | coihaique
# Processing Record 16 of Set 7 | the valley
# Processing Record 17 of Set 7 | minab
# Processing Record 18 of Set 7 | ozernovskiy
# Processing Record 19 of Set 7 | vallenar
# Processing Record 20 of Set 7 | senekal
# Processing Record 21 of Set 7 | quatre cocos
# Processing Record 22 of Set 7 | deputatskiy
# Processing Record 23 of Set 7 | guigue
# Processing Record 24 of Set 7 | salalah
# Processing Record 25 of Set 7 | athabasca
# Processing Record 26 of Set 7 | turukhansk
# Processing Record 27 of Set 7 | aksum
# Processing Record 28 of Set 7 | tubarao
# Processing Record 29 of Set 7 | amalapuram
# Processing Record 30 of Set 7 | mahebourg
# Processing Record 31 of Set 7 | zhicheng
# Processing Record 32 of Set 7 | bara
# Processing Record 33 of Set 7 | vetlanda
# Processing Record 34 of Set 7 | san cristobal
# Processing Record 35 of Set 7 | mogadishu
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | abha
# Processing Record 40 of Set 7 | ixtapa
# Processing Record 41 of Set 7 | nalut
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | camrose
# Processing Record 44 of Set 7 | malatya
# Processing Record 45 of Set 7 | codrington
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | mossendjo
# Processing Record 48 of Set 7 | bethel
# Processing Record 49 of Set 7 | brae
# Processing Record 50 of Set 7 | talavera de la reina
# Processing Record 1 of Set 8 | klyuchi
# Processing Record 2 of Set 8 | haines junction
# Processing Record 3 of Set 8 | bambanglipuro
# Processing Record 4 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | paita
# Processing Record 7 of Set 8 | ormara
# Processing Record 8 of Set 8 | alta floresta
# Processing Record 9 of Set 8 | galle
# Processing Record 10 of Set 8 | huarmey
# Processing Record 11 of Set 8 | alofi
# Processing Record 12 of Set 8 | balkanabat
# Processing Record 13 of Set 8 | cabinda
# Processing Record 14 of Set 8 | upernavik
# Processing Record 15 of Set 8 | san lazaro
# Processing Record 16 of Set 8 | abramovka
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | shumikha
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | ranong
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | port pirie
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | moerai
# Processing Record 25 of Set 8 | olinda
# Processing Record 26 of Set 8 | antofagasta
# Processing Record 27 of Set 8 | torbay
# Processing Record 28 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 29 of Set 8 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 30 of Set 8 | omsukchan
# Processing Record 31 of Set 8 | watsa
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | porto novo
# Processing Record 34 of Set 8 | betioky
# Processing Record 35 of Set 8 | gannan
# Processing Record 36 of Set 8 | san quintin
# Processing Record 37 of Set 8 | tarauaca
# Processing Record 38 of Set 8 | touros
# Processing Record 39 of Set 8 | dindigul
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | hithadhoo
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | velka nad velickou
# Processing Record 44 of Set 8 | zaysan
# Processing Record 45 of Set 8 | kansanshi
# Processing Record 46 of Set 8 | berkak
# Processing Record 47 of Set 8 | ornes
# Processing Record 48 of Set 8 | ambon
# Processing Record 49 of Set 8 | muros
# Processing Record 50 of Set 8 | sao jose da coroa grande
# Processing Record 1 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 9 | saint-augustin
# Processing Record 3 of Set 9 | vostok
# Processing Record 4 of Set 9 | mayo
# Processing Record 5 of Set 9 | novyy starodub
# Processing Record 6 of Set 9 | riyadh
# Processing Record 7 of Set 9 | sidi ali
# Processing Record 8 of Set 9 | vicuna
# Processing Record 9 of Set 9 | birao
# Processing Record 10 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 9 | namatanai
# Processing Record 12 of Set 9 | talara
# Processing Record 13 of Set 9 | belmonte
# Processing Record 14 of Set 9 | kurumkan
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | tommot
# Processing Record 17 of Set 9 | lianzhou
# Processing Record 18 of Set 9 | saint-francois
# Processing Record 19 of Set 9 | mao
# Processing Record 20 of Set 9 | zabol
# Processing Record 21 of Set 9 | bubaque
# Processing Record 22 of Set 9 | hambantota
# Processing Record 23 of Set 9 | provideniya
# Processing Record 24 of Set 9 | abu zabad
# Processing Record 25 of Set 9 | sao filipe
# Processing Record 26 of Set 9 | hwange
# Processing Record 27 of Set 9 | mount isa
# Processing Record 28 of Set 9 | prince rupert
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | pangai
# Processing Record 31 of Set 9 | padang
# Processing Record 32 of Set 9 | eyl
# Processing Record 33 of Set 9 | powell
# Processing Record 34 of Set 9 | tiarei
# Processing Record 35 of Set 9 | chara
# Processing Record 36 of Set 9 | oistins
# Processing Record 37 of Set 9 | rioja
# Processing Record 38 of Set 9 | kidal
# Processing Record 39 of Set 9 | rapid valley
# Processing Record 40 of Set 9 | mantua
# Processing Record 41 of Set 9 | cayenne
# Processing Record 42 of Set 9 | baisha
# Processing Record 43 of Set 9 | sarangani
# Processing Record 44 of Set 9 | ozerne
# Processing Record 45 of Set 9 | puerto gaitan
# Processing Record 46 of Set 9 | onega
# Processing Record 47 of Set 9 | benjamin hill
# Processing Record 48 of Set 9 | beloha
# Processing Record 49 of Set 9 | dudinka
# Processing Record 50 of Set 9 | flinders
# Processing Record 1 of Set 10 | chico
# Processing Record 2 of Set 10 | cosala
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | keflavik
# Processing Record 5 of Set 10 | westport
# Processing Record 6 of Set 10 | durazno
# Processing Record 7 of Set 10 | mbour
# Processing Record 8 of Set 10 | manggar
# Processing Record 9 of Set 10 | burnie
# Processing Record 10 of Set 10 | cairns
# Processing Record 11 of Set 10 | businga
# Processing Record 12 of Set 10 | evensk
# Processing Record 13 of Set 10 | lewistown
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | camaqua
# Processing Record 16 of Set 10 | katha
# City not found. Skipping...
# Processing Record 17 of Set 10 | yatou
# Processing Record 18 of Set 10 | buraydah
# Processing Record 19 of Set 10 | yulara
# Processing Record 20 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 10 | lakes entrance
# Processing Record 22 of Set 10 | telimele
# Processing Record 23 of Set 10 | helong
# Processing Record 24 of Set 10 | jakhal mandi
# City not found. Skipping...
# Processing Record 25 of Set 10 | trinidad
# Processing Record 26 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 10 | finschhafen
# Processing Record 28 of Set 10 | biak
# Processing Record 29 of Set 10 | gisborne
# Processing Record 30 of Set 10 | fukue
# Processing Record 31 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | yerbogachen
# Processing Record 34 of Set 10 | tokonou
# Processing Record 35 of Set 10 | roma
# Processing Record 36 of Set 10 | kanigoro
# Processing Record 37 of Set 10 | chimbote
# Processing Record 38 of Set 10 | clinton
# Processing Record 39 of Set 10 | saurimo
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | nuuk
# Processing Record 42 of Set 10 | yangambi
# Processing Record 43 of Set 10 | sergeyevka
# Processing Record 44 of Set 10 | bartica
# Processing Record 45 of Set 10 | nome
# Processing Record 46 of Set 10 | hammerfest
# Processing Record 47 of Set 10 | barra patuca
# Processing Record 48 of Set 10 | irati
# Processing Record 49 of Set 10 | keti bandar
# Processing Record 50 of Set 10 | conceicao do coite
# Processing Record 1 of Set 11 | arrecife
# Processing Record 2 of Set 11 | hermiston
# Processing Record 3 of Set 11 | lorengau
# Processing Record 4 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 5 of Set 11 | sainte-marie
# Processing Record 6 of Set 11 | oranjemund
# Processing Record 7 of Set 11 | mareeba
# Processing Record 8 of Set 11 | lima
# Processing Record 9 of Set 11 | isiro
# Processing Record 10 of Set 11 | votkinsk
# Processing Record 11 of Set 11 | tshikapa
# Processing Record 12 of Set 11 | hervey bay
# Processing Record 13 of Set 11 | gigmoto
# Processing Record 14 of Set 11 | brejo
# Processing Record 15 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 11 | korla
# Processing Record 17 of Set 11 | duluth
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | sistranda
# Processing Record 20 of Set 11 | adrar
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | taywarah
# Processing Record 23 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 11 | honiara
# Processing Record 25 of Set 11 | belfast
# Processing Record 26 of Set 11 | teya
# Processing Record 27 of Set 11 | darhan
# Processing Record 28 of Set 11 | kumeny
# Processing Record 29 of Set 11 | bosaso
# Processing Record 30 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 11 | tilichiki
# Processing Record 32 of Set 11 | kloulklubed
# Processing Record 33 of Set 11 | college
# Processing Record 34 of Set 11 | harlau
# Processing Record 35 of Set 11 | san policarpo
# Processing Record 36 of Set 11 | port augusta
# Processing Record 37 of Set 11 | kununurra
# Processing Record 38 of Set 11 | tucuma
# Processing Record 39 of Set 11 | loandjili
# Processing Record 40 of Set 11 | nishihara
# Processing Record 41 of Set 11 | brownsville
# Processing Record 42 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 11 | ancud
# Processing Record 44 of Set 11 | winnemucca
# Processing Record 45 of Set 11 | middlebury
# Processing Record 46 of Set 11 | bairiki
# Processing Record 47 of Set 11 | daur
# Processing Record 48 of Set 11 | jeffersontown
# Processing Record 49 of Set 11 | atherton
# Processing Record 50 of Set 11 | abnub
# Processing Record 1 of Set 12 | palauig
# Processing Record 2 of Set 12 | forestville
# Processing Record 3 of Set 12 | thinadhoo
# Processing Record 4 of Set 12 | ostersund
# Processing Record 5 of Set 12 | sao joao del rei
# Processing Record 6 of Set 12 | chapais
# Processing Record 7 of Set 12 | san juan
# Processing Record 8 of Set 12 | whitehorse
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | gat
# Processing Record 11 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 12 | estelle
# Processing Record 13 of Set 12 | sihor
# Processing Record 14 of Set 12 | konstantinovka
# Processing Record 15 of Set 12 | chissamba
# Processing Record 16 of Set 12 | kalemie
# Processing Record 17 of Set 12 | haveli
# Processing Record 18 of Set 12 | ulaanbaatar
# Processing Record 19 of Set 12 | barentu
# Processing Record 20 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 12 | puerto lempira
# Processing Record 22 of Set 12 | saint-denis
# Processing Record 23 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 12 | imbituba
# Processing Record 25 of Set 12 | vestmannaeyjar
# Processing Record 26 of Set 12 | shahreza
# Processing Record 27 of Set 12 | santa cruz
# Processing Record 28 of Set 12 | la roda
# Processing Record 29 of Set 12 | wewak
# Processing Record 30 of Set 12 | arteaga
# Processing Record 31 of Set 12 | samsun
# Processing Record 32 of Set 12 | vanimo
# Processing Record 33 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 34 of Set 12 | arman
# Processing Record 35 of Set 12 | sanming
# Processing Record 36 of Set 12 | tari
# Processing Record 37 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 12 | kayerkan
# Processing Record 39 of Set 12 | ilinskiy
# Processing Record 40 of Set 12 | weinan
# Processing Record 41 of Set 12 | novyy urengoy
# Processing Record 42 of Set 12 | avera
# Processing Record 43 of Set 12 | kapoeta
# Processing Record 44 of Set 12 | pervomayskoye
# Processing Record 45 of Set 12 | goose creek
# Processing Record 46 of Set 12 | harper
# Processing Record 47 of Set 12 | mweka
# Processing Record 48 of Set 12 | alice springs
# Processing Record 49 of Set 12 | kahului
# Processing Record 50 of Set 12 | tsentralnyy
# City not found. Skipping...
# Processing Record 1 of Set 13 | craig
# Processing Record 2 of Set 13 | sao lourenco do sul
# Processing Record 3 of Set 13 | nizhniy kuranakh
# Processing Record 4 of Set 13 | dingle
# Processing Record 5 of Set 13 | gladstone
# Processing Record 6 of Set 13 | fakel
# Processing Record 7 of Set 13 | senno
# Processing Record 8 of Set 13 | puerto escondido
# Processing Record 9 of Set 13 | honningsvag
# Processing Record 10 of Set 13 | fenoarivo
# Processing Record 11 of Set 13 | barranca
# Processing Record 12 of Set 13 | totma
# Processing Record 13 of Set 13 | temir
# Processing Record 14 of Set 13 | khandyga
# Processing Record 15 of Set 13 | poso
# Processing Record 16 of Set 13 | pangody
# Processing Record 17 of Set 13 | kashi
# Processing Record 18 of Set 13 | gravdal
# Processing Record 19 of Set 13 | kyabe
# Processing Record 20 of Set 13 | altamira
# Processing Record 21 of Set 13 | bilibino
# Processing Record 22 of Set 13 | nkowakowa
# Processing Record 23 of Set 13 | broome
# Processing Record 24 of Set 13 | waipawa
# Processing Record 25 of Set 13 | lucapa
# Processing Record 26 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 13 | luanda
# Processing Record 28 of Set 13 | la ronge
# Processing Record 29 of Set 13 | palmer
# Processing Record 30 of Set 13 | fengrun
# Processing Record 31 of Set 13 | hami
# Processing Record 32 of Set 13 | serenje
# Processing Record 33 of Set 13 | jasper
# Processing Record 34 of Set 13 | at-bashi
# Processing Record 35 of Set 13 | tura
# Processing Record 36 of Set 13 | roebourne
# Processing Record 37 of Set 13 | karpathos
# Processing Record 38 of Set 13 | nicoya
# Processing Record 39 of Set 13 | port blair
# Processing Record 40 of Set 13 | seoul
# Processing Record 41 of Set 13 | khandbari
# Processing Record 42 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 13 | sibolga
# Processing Record 44 of Set 13 | bafq
# Processing Record 45 of Set 13 | verkhnevilyuysk
# Processing Record 46 of Set 13 | kieta
# Processing Record 47 of Set 13 | bana
# Processing Record 48 of Set 13 | sokoni
# Processing Record 49 of Set 13 | caravelas
# Processing Record 50 of Set 13 | nanning
# Processing Record 1 of Set 14 | ostrov
# Processing Record 2 of Set 14 | comodoro rivadavia
# Processing Record 3 of Set 14 | puerto madryn
# Processing Record 4 of Set 14 | road town
# Processing Record 5 of Set 14 | toktogul
# Processing Record 6 of Set 14 | huilong
# Processing Record 7 of Set 14 | ukiah
# Processing Record 8 of Set 14 | sovetskiy
# Processing Record 9 of Set 14 | kargasok
# Processing Record 10 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 14 | paragominas
# Processing Record 12 of Set 14 | santa rosa
# Processing Record 13 of Set 14 | takaka
# Processing Record 14 of Set 14 | stawell
# Processing Record 15 of Set 14 | peterhead
# Processing Record 16 of Set 14 | vanavara
# Processing Record 17 of Set 14 | stornoway
# Processing Record 18 of Set 14 | talaya
# Processing Record 19 of Set 14 | alugan
# Processing Record 20 of Set 14 | kandrian
# Processing Record 21 of Set 14 | vryheid
# Processing Record 22 of Set 14 | winslow
# Processing Record 23 of Set 14 | young
# Processing Record 24 of Set 14 | cabo san lucas
# Processing Record 25 of Set 14 | jaicos
# Processing Record 26 of Set 14 | pingliang
# Processing Record 27 of Set 14 | savannah bight
# Processing Record 28 of Set 14 | tokur
# Processing Record 29 of Set 14 | bikin
# Processing Record 30 of Set 14 | sumter
# Processing Record 31 of Set 14 | yar-sale
# Processing Record 32 of Set 14 | concarneau
# Processing Record 33 of Set 14 | konevo
# Processing Record 34 of Set 14 | iracoubo
# Processing Record 35 of Set 14 | saint anthony
# Processing Record 36 of Set 14 | mackay
# Processing Record 37 of Set 14 | acapulco
# Processing Record 38 of Set 14 | kilindoni
# Processing Record 39 of Set 14 | ndola
# Processing Record 40 of Set 14 | daru
# Processing Record 41 of Set 14 | auki
# Processing Record 42 of Set 14 | russell
# Processing Record 43 of Set 14 | zhezkazgan
# Processing Record 44 of Set 14 | mezen
# Processing Record 45 of Set 14 | rafai
# Processing Record 46 of Set 14 | bucerias
# Processing Record 47 of Set 14 | aquiraz
# Processing Record 48 of Set 14 | corinto
# Processing Record 49 of Set 14 | nyurba
# Processing Record 50 of Set 14 | mahon
# Processing Record 1 of Set 15 | kalianget
# Processing Record 2 of Set 15 | port-cartier
# Processing Record 3 of Set 15 | vrangel
# Processing Record 4 of Set 15 | svetlyy
# Processing Record 5 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 6 of Set 15 | plyussa
# Processing Record 7 of Set 15 | wajima
# Processing Record 8 of Set 15 | jucas
# Processing Record 9 of Set 15 | mehriz
# Processing Record 10 of Set 15 | ploemeur
# Processing Record 11 of Set 15 | iralaya
# Processing Record 12 of Set 15 | merauke
# Processing Record 13 of Set 15 | panzhihua
# Processing Record 14 of Set 15 | villers-les-nancy
# Processing Record 15 of Set 15 | san antonio
# Processing Record 16 of Set 15 | arawa
# Processing Record 17 of Set 15 | choctaw
# Processing Record 18 of Set 15 | buala
# Processing Record 19 of Set 15 | anadyr
# Processing Record 20 of Set 15 | weligama
# Processing Record 21 of Set 15 | anchorage
# Processing Record 22 of Set 15 | isabela
# Processing Record 23 of Set 15 | lengshuitan
# Processing Record 24 of Set 15 | itarema
# Processing Record 25 of Set 15 | dryden
# Processing Record 26 of Set 15 | mazkeret batya
# Processing Record 27 of Set 15 | peniche
# Processing Record 28 of Set 15 | rorvik
# Processing Record 29 of Set 15 | rawson
# Processing Record 30 of Set 15 | jiuquan
# Processing Record 31 of Set 15 | djibo
# Processing Record 32 of Set 15 | aska
# Processing Record 33 of Set 15 | tenenkou
# Processing Record 34 of Set 15 | diego de almagro
# Processing Record 35 of Set 15 | lisakovsk
# Processing Record 36 of Set 15 | sotnikovo
# Processing Record 37 of Set 15 | kimbe
# Processing Record 38 of Set 15 | upata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
vacation_data_df = pd.DataFrame(vacation_data)
vacation_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
vacation_data_df.to_csv(output_data_file, index_label="City_ID")
